# %% [markdown]
# see https://s3.amazonaws.com/amazon-reviews-pds/tsv/index.txt

# %%
import tensorflow as tf
import os

import gzip
import shutil
import pandas as pd

# %%
def getAmazonDataFrame(filename):
  p = tf.keras.utils.get_file(filename, 
                            origin="https://s3.amazonaws.com/amazon-reviews-pds/tsv/" + filename, 
                            extract=True, cache_dir=".", cache_subdir="")
  #print(p)
  #gunzip(p)
  with open(p[0:-3], 'wb') as f_out, gzip.open(p, 'rb') as f_in:
    shutil.copyfileobj(f_in, f_out)
    
  frame = pd.read_csv(p[0:-3], sep='\t', error_bad_lines=False)
  return frame

# %%
x = getAmazonDataFrame("amazon_reviews_multilingual_DE_v1_00.tsv.gz")
print(x.shape)
x.head()
# Out:
# ...
# 241901568/241896005 [==============================] - 3s 0us/step
# (678993, 15)
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          DE        10133   RVOG49N0H1FB6  B004TACMZ8       569741360
# 1          DE        19612   RNCMD6OLTP4HM  1846071224       785505948
# 2          DE        19612   R4AUOBI8YC0R8  0375851569       516548029
# 3          DE        19677  R1VSHIJ1RHIBTE  B0060SVG54       302116447
# 4          DE        19999  R3JBLVALWSLCZD  B00EYQ6CVC       368843515
#
#                                        product_title  product_category  \
# 0    Bosch GMS120 Ortungsgerät digital multi-Scanner  Home Improvement
# 1  The Wheels On The Bus: Favourite Nursery Rhyme...             Books
# 2              Dr. Seuss's  Beginner Book Collection             Books
# 3                                  Zwei an einem Tag         Video DVD
# 4  Dr. House - Die komplette Serie, Season 1-8 (L...         Video DVD
#
# ...

# %%
x = getAmazonDataFrame("amazon_reviews_multilingual_US_v1_00.tsv.gz")
print(x.shape)
x.head()
# Out:
# ...
# 1466966016/1466965039 [==============================] - 19s 0us/step
# b'Skipping line 3231472: expected 15 fields, saw 22\n'
# b'Skipping line 3509762: expected 15 fields, saw 22\n'
# b'Skipping line 4018793: expected 15 fields, saw 22\n'
# b'Skipping line 4280173: expected 15 fields, saw 22\nSkipping line 4290596: expected 15 fields, saw 22\n'
# b'Skipping line 4331421: expected 15 fields, saw 22\nSkipping line 4340267: expected 15 fields, saw 22\nSkipping line 4341665: expected 15 fields, saw 22\nSkipping line 4386155: expected 15 fields, saw 22\nSkipping line 4388098: expected 15 fields, saw 22\n'
# b'Skipping line 4408027: expected 15 fields, saw 22\nSkipping line 4442615: expected 15 fields, saw 22\n'
# b'Skipping line 4519623: expected 15 fields, saw 22\n'
# b'Skipping line 4525797: expected 15 fields, saw 22\nSkipping line 4543519: expected 15 fields, saw 22\n'
# ...

# %%
x = getAmazonDataFrame("amazon_reviews_multilingual_UK_v1_00.tsv.gz")
print(x.shape)
x.head()
# Out:
# ...
# 349372416/349370868 [==============================] - 17s 0us/step
# b'Skipping line 101882: expected 15 fields, saw 22\nSkipping line 115512: expected 15 fields, saw 22\n'
# b'Skipping line 328404: expected 15 fields, saw 22\n'
# b'Skipping line 1412642: expected 15 fields, saw 22\n'
# (1705837, 15)
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          UK        10349  R2YVNBBMXD8KVJ  B00MWK7BWG       307651059
# 1          UK        10629  R2K4BOL8MN1TTY  B006CHML4I       835010224
# 2          UK        12136  R3P40IEALROVCH  B00IIFCJX0       271687675
# 3          UK        12268  R25XL1WWYRDLA9  B000W7JWUA       211383699
# 4          UK        12677   RVTVB9YDXSFYH  B005JTAP4S       182965893
#
#                                        product_title        product_category  \
# 0                         My Favourite Faded Fantasy                   Music
# 1  Seiko 5 Men's Automatic Watch with Black Dial ...                 Watches
# ...
