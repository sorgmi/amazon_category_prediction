# %%
# %load_ext autoreload
# %autoreload 2

# !pip3 install --quiet tensorflow-gpu==1.13.1
# !pip3 install --quiet tensorflow-hub
# !pip3 install --quiet tf-sentencepiece

import tensorflow as tf
print("Version: ", tf.__version__)
print("Eager mode: ", tf.executing_eagerly())
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")

import os, sys
from google.colab import drive
drive.mount('/content/gdrive')
gitDir = "/content/gdrive/My Drive/nlp/"
os.chdir(gitDir + "training/")
os.chdir(gitDir)
print(os.listdir("."))

#sys.path.insert(0,gitDir + "data")

import training.train as t
# Out:
# Version:  1.13.1
# Eager mode:  False
# GPU is available
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ['.git', 'README.md', 'data', 'presentations', '.idea', 'training', 'blobs', '.gitignore', 'serverblobs', 'template.py', 'report.ipynb', '.ipynb_checkpoints']

# %%
# %%time

params = {}
params["trainData"] = "organic_train_attribute"
params["testData"] = "organic_test_attribute"
params["checkpoint"] = False
params["epochs"] = 50
params["batchSize"] = 256
params["optimizer"] = tf.train.AdamOptimizer()
params["trainexamples"] = None
params["architecture"] = [False]
params["f1modus"] = "micro"
params["savelog"] = True
params["path"] = "blobs/" + "2019-06-23" + "_organic_baseline_attribute/"
params["notebook"] = True
params["showPlots"] = False
    
result = t.trainModel(params)
# Out:
# classes: 14
# saving to: blobs/2019-06-23_organic_baseline_attribute/
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0624 11:48:32.291131 140391015999360 saver.py:1483] Saver not created because there are no variables in the graph to restore
# ...
# 	Epoch 1: train_loss: 2.5624, train_acc: 0.2101, train_micro-f1: 0.2061 || val_loss: 2.4897, val_acc: 0.2976, val_micro-f1: 0.2913
#               precision    recall  f1-score   support
#
#            0       0.35      0.67      0.46       143
#            1       0.50      0.03      0.06        30
#            2       0.00      0.00      0.00        15
#            3       0.00      0.00      0.00        33
#            4       0.00      0.00      0.00        19
#            5       0.13      0.34      0.19        32
#            6       0.27      0.37      0.31        71
#            7       0.00      0.00      0.00        37
#            8       0.00      0.00      0.00        13
# ...

# %%
# %%time

params = {}
params["trainData"] = "organic_train_relevance"
params["testData"] = "organic_test_relevance"
params["checkpoint"] = False
params["epochs"] = 50
params["batchSize"] = 256
params["optimizer"] = tf.train.AdamOptimizer()
params["trainexamples"] = None
params["architecture"] = [False]
params["f1modus"] = "micro"
params["savelog"] = True
params["path"] = "blobs/" + "2019-06-23" + "_organic_baseline_relevance/"
params["notebook"] = True
params["showPlots"] = False
    
result = t.trainModel(params)
# Out:
# classes: 2
# saving to: blobs/2019-06-23_organic_baseline_relevance/
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0624 11:53:42.622663 140391015999360 saver.py:1483] Saver not created because there are no variables in the graph to restore
# ...
# 	Epoch 1: train_loss: 0.6801, train_acc: 0.5566, train_micro-f1: 0.5597 || val_loss: 0.6749, val_acc: 0.5425, val_micro-f1: 0.5744
#               precision    recall  f1-score   support
#
#            0       0.86      0.16      0.27       447
#            1       0.55      0.97      0.70       460
#
#     accuracy                           0.57       907
#    macro avg       0.70      0.57      0.49       907
# weighted avg       0.70      0.57      0.49       907
#
# saving results to: blobs/2019-06-23_organic_baseline_relevance/
# ...
# 	Epoch 2: train_loss: 0.6460, train_acc: 0.6165, train_micro-f1: 0.6165 || val_loss: 0.6545, val_acc: 0.5873, val_micro-f1: 0.6185
# ...

# %%
# %%time

params = {}
params["trainData"] = "organic_train_entity"
params["testData"] = "organic_test_entity"
params["checkpoint"] = False
params["epochs"] = 50
params["batchSize"] = 256
params["optimizer"] = tf.train.AdamOptimizer()
params["trainexamples"] = None
params["architecture"] = [False]
params["f1modus"] = "micro"
params["savelog"] = True
params["path"] = "blobs/" + "2019-06-23" + "_organic_baseline_entity/"
params["notebook"] = True
params["showPlots"] = False
    
result = t.trainModel(params)
# Out:
# classes: 9
# saving to: blobs/2019-06-23_organic_baseline_entity/
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0624 12:01:43.739218 140391015999360 saver.py:1483] Saver not created because there are no variables in the graph to restore
# ...
# 	Epoch 1: train_loss: 2.0881, train_acc: 0.3361, train_micro-f1: 0.3311 || val_loss: 1.9768, val_acc: 0.4428, val_micro-f1: 0.4391
#               precision    recall  f1-score   support
#
#            0       0.38      0.08      0.13       105
#            1       0.45      0.89      0.60       186
#            2       0.43      0.35      0.38        83
#            3       0.00      0.00      0.00        26
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00        21
#            6       0.00      0.00      0.00        27
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00         6
#
# ...

# %% [markdown]
# # with xling fine-tune

# %%
# %%time

params = {}
params["trainData"] = "organic_train_attribute"
params["testData"] = "organic_test_attribute"
params["checkpoint"] = False
params["epochs"] = 50
params["batchSize"] = 256
params["optimizer"] = tf.train.AdamOptimizer(epsilon=1e-3)
params["trainexamples"] = None
params["architecture"] = [True]
params["f1modus"] = "micro"
params["savelog"] = True
params["path"] = "blobs/" + "2019-06-23" + "_organic_baseline_attribute_xling/"
params["notebook"] = True
params["showPlots"] = False
    
result = t.trainModel(params)
# Out:
# classes: 14
# saving to: blobs/2019-06-23_organic_baseline_attribute_xling/
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0624 12:06:58.647145 140391015999360 saver.py:1483] Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# W0624 12:07:00.212260 140391015999360 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ...

# %%
# %%time

params = {}
params["trainData"] = "organic_train_relevance"
params["testData"] = "organic_test_relevance"
params["checkpoint"] = False
params["epochs"] = 50
params["batchSize"] = 256
params["optimizer"] = tf.train.AdamOptimizer(epsilon=1e-3)
params["trainexamples"] = None
params["architecture"] = [True]
params["f1modus"] = "micro"
params["savelog"] = True
params["path"] = "blobs/" + "2019-06-23" + "_organic_baseline_relevance_xling/"
params["notebook"] = True
params["showPlots"] = False
    
result = t.trainModel(params)
# Out:
# classes: 2
# saving to: blobs/2019-06-23_organic_baseline_relevance_xling/
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0624 12:18:48.341329 140391015999360 saver.py:1483] Saver not created because there are no variables in the graph to restore
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# ...
# 	Epoch 1: train_loss: 0.6833, train_acc: 0.5509, train_micro-f1: 0.5522 || val_loss: 0.6751, val_acc: 0.5575, val_micro-f1: 0.5877
#               precision    recall  f1-score   support
#
#            0       0.86      0.19      0.32       447
#            1       0.55      0.97      0.70       460
#
#     accuracy                           0.59       907
#    macro avg       0.71      0.58      0.51       907
# ...

# %%
# %%time

params = {}
params["trainData"] = "organic_train_entity"
params["testData"] = "organic_test_entity"
params["checkpoint"] = False
params["epochs"] = 50
params["batchSize"] = 256
params["optimizer"] = tf.train.AdamOptimizer(epsilon=1e-3)
params["trainexamples"] = None
params["architecture"] = [True]
params["f1modus"] = "micro"
params["savelog"] = True
params["path"] = "blobs/" + "2019-06-23" + "_organic_baseline_entity_xling/"
params["notebook"] = True
params["showPlots"] = False
    
result = t.trainModel(params)
# Out:
# classes: 9
# saving to: blobs/2019-06-23_organic_baseline_entity_xling/
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# I0624 12:37:56.748975 140391015999360 saver.py:1483] Saver not created because there are no variables in the graph to restore
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# ...
# 	Epoch 1: train_loss: 2.1405, train_acc: 0.2577, train_micro-f1: 0.2507 || val_loss: 2.0358, val_acc: 0.4331, val_micro-f1: 0.4283
#               precision    recall  f1-score   support
#
#            0       0.40      0.04      0.07       105
#            1       0.42      0.98      0.59       186
#            2       0.62      0.12      0.20        83
#            3       0.00      0.00      0.00        26
# ...
